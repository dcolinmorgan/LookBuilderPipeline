# %%
from LookBuilderPipeline.utils.resize import resize_images
from LookBuilderPipeline.image_models.image_model_sdxl import ImageModelSDXL
from LookBuilderPipeline.image_models.base_image_model import BaseImageModel

# %%
image_model = BaseImageModel(image='/Users/apple/Developer/modegen/LookBuilderPipeline/LookBuilderPipeline/img/p09.jpg', **kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 image_model = BaseImageModel(image='/Users/apple/Developer/modegen/LookBuilderPipeline/LookBuilderPipeline/img/p09.jpg', **kwargs)
#
# NameError: name 'kwargs' is not defined

# %%
A,B,C,D=resize_images([image_model.image,image_model.pose,image_model.mask,image_model.outfit],1024,square=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 A,B,C,D=resize_images([image_model.image,image_model.pose,image_model.mask,image_model.outfit],1024,square=True)
#
# AttributeError: 'BaseImageModel' object has no attribute 'outfit'

# %%
image_model = ImageModelSDXL(image='/Users/apple/Developer/modegen/LookBuilderPipeline/LookBuilderPipeline/img/p09.jpg', pose=None, mask=None, prompt='woman on beach')

# %%
# image_model.strength=1.0

image_model.num_inference_steps=20
image_model.prepare_model()
# Out:
# An error occurred while trying to fetch thibaud/controlnet-openpose-sdxl-1.0: thibaud/controlnet-openpose-sdxl-1.0 does not appear to have a file named diffusion_pytorch_model.safetensors.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
image_model.generate_image()
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
import io
from PIL import Image
from diffusers.utils import load_image

image = load_image('/Users/apple/Developer/modegen/LookBuilderPipeline/LookBuilderPipeline/img/p09.jpg')
load_image(image)
# Out:
# <PIL.Image.Image image mode=RGB size=790x1204>
